# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# 한글설정
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic' # Win용
# matplotlib.rcParams['font.family'] = 'AppleGothic' # Mac용
matplotlib.rcParams['font.size'] = 15 # 글자크기
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
df = pd.read_excel('score.xlsx',index_col='지원번호')

# %%
def cm_func(x):
  return str(x)+'cm'

# df['키'] : 배열타입의 모든 것을 함수적용 - apply
df['키'] = df['키'].apply(cm_func)
df['키']
# Out:
# 지원번호
# 1번    197cm
# 2번    184cm
# 3번    168cm
# 4번    187cm
# 5번    188cm
# 6번    202cm
# 7번    188cm
# 8번    190cm
# Name: 키, dtype: object

# %%
## 50점 아래 있는 값 : 50으로 리턴해서 출력하시오.
def k_func(x):
  if x<50: return 50
  return x

### int,float,str 단일값은 함수명(데이터)으로 호출
for i in range(8):
  print(k_func(df['국어'][i]))
# Out:
# 90
# 50
# 80
# 50
# 50
# 80
# 55
# 100
# C:\Users\KOSMO\AppData\Local\Temp\ipykernel_18128\1520184859.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(k_func(df['국어'][i]))

# %%
def h_func(x):
  return int(x/2)

### 누적막대그래프를 사용해서 값들을 모두 중앙에 출력하시오.

plt.figure(figsize=(8,4))
plt.title("학생성적그래프")
plt.bar(df['이름'],df['국어'],width=0.6,label='국어')
plt.bar(df['이름'],df['영어'],bottom=df['국어'],width=0.6,label='영어')
plt.bar(df['이름'],df['수학'],bottom=df['국어']+df['영어'],width=0.6,label='수학')
# plt.legend(ncol=3)
# n_list = df['국어'].apply(func)
## 데이터가 단일타입 - int,float,str
for i in range(8):
  plt.text(df['이름'][i],h_func(df['국어'][i]),df['국어'][i],ha='center')
  plt.text(df['이름'][i],h_func((df['국어'][i]+df['국어'][i]+df['영어'][i])),df['영어'][i],ha='center')
  plt.text(df['이름'][i],h_func((df['국어'][i]+df['국어'][i]+df['영어'][i]+df['영어'][i]+df['수학'][i])),df['수학'][i],ha='center')
# Out:
# C:\Users\KOSMO\AppData\Local\Temp\ipykernel_18128\1376530226.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.text(df['이름'][i],h_func(df['국어'][i]),df['국어'][i],ha='center')
# C:\Users\KOSMO\AppData\Local\Temp\ipykernel_18128\1376530226.py:16: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.text(df['이름'][i],h_func((df['국어'][i]+df['국어'][i]+df['영어'][i])),df['영어'][i],ha='center')
# ...
