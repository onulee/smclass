# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# 한글설정
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic' # Win용
# matplotlib.rcParams['font.family'] = 'AppleGothic' # Mac용
matplotlib.rcParams['font.size'] = 15 # 글자크기
matplotlib.rcParams['axes.unicode_minus'] = False

# df = pd.read_excel('score.xlsx',index_col='지원번호')

# %%
df = pd.read_csv('chipotle.tsv',sep='\t')

# %%
df.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
df.groupby('item_name')['order_id'].count().head(10)
# Out:
# item_name
# 6 Pack Soft Drink         54
# Barbacoa Bowl             66
# Barbacoa Burrito          91
# Barbacoa Crispy Tacos     11
# Barbacoa Salad Bowl       10
# Barbacoa Soft Tacos       25
# Bottled Water            162
# Bowl                       2
# Burrito                    6
# Canned Soda              104
# Name: order_id, dtype: int64

# %%
df.groupby('item_name')['order_id'].count().mean()
# Out:
# np.float64(92.44)

# %%
type(df.groupby('item_name')['order_id'].count().mean())
# Out:
# numpy.float64

# %%
count_df['mean'] = df.groupby('item_name')['order_id'].count().mean()

# %%
count_df
# Out:
# item_name
# 6 Pack Soft Drink         54.00
# Barbacoa Bowl             66.00
# Barbacoa Burrito          91.00
# Barbacoa Crispy Tacos     11.00
# Barbacoa Salad Bowl       10.00
# Barbacoa Soft Tacos       25.00
# Bottled Water            162.00
# Bowl                       2.00
# Burrito                    6.00
# Canned Soda              104.00
# mean                      92.44
# Name: order_id, dtype: float64

# %%
## 메뉴별 주문개수
## 순서상관없이, head(10)로 10개 막대그래프를 출력하시오.
count_df = df.groupby('item_name')['order_id'].count().head(10)
## 평균포함
count_df['mean'] = df.groupby('item_name')['order_id'].count().mean()
count_df.index
plt.xticks(rotation=90)
plt.grid(axis='y', alpha=0.5)
count_bar = plt.bar(count_df.index,count_df)
count_bar[len(count_df.index)-1].set_color('red')
plt.plot(count_df.index,[count_df.loc['mean']]*len(count_df.index),color='black',ls='--')
plt.show()

# %%
count_df.loc['mean']
# Out:
# np.float64(92.44)
